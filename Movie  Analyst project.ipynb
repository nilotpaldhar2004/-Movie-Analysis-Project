# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib 
import matplotlib.pyplot as plt
import matplotlib 
plt.style.use('ggplot')
matplotlib.rcParams['figure.figsize'] = (12,8)
pd.options.mode.chained_assignment=None
df=pd.read_csv(r"C:\Users\dharn\Downloads\movies.csv")

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
# More efficient missing values analysis
missing_values = df.isnull().mean() * 100
print(missing_values.sort_values(ascending=False))
# Out:
# budget      28.312467
# gross        2.464789
# rating       1.004173
# company      0.221701
# runtime      0.052165
# score        0.039124
# votes        0.039124
# writer       0.039124
# country      0.039124
# released     0.026082
# star         0.013041
# name         0.000000
# genre        0.000000
# year         0.000000
# director     0.000000
# dtype: float64

# %%
# Quick dataset overview
print(f"Dataset shape: {df.shape}")
print("\nFirst few rows:")
print(df.head())
# Out:
# Dataset shape: (7668, 15)
#
# First few rows:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
# ...

# %%
print(df.dtypes)
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# To compare gross revenue across different genres or ratings
plt.figure(figsize=(14, 8))
sns.boxplot(x='genre', y='gross', data=df)

plt.title('Gross Revenue by Genre')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Before running drop_duplicates
original_rows = len(df)

# %%
df.drop_duplicates()
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
# After running drop_duplicates
new_rows = len(df)

print(f"Removed {original_rows - new_rows} duplicate rows")
# Out:
# Removed 0 duplicate rows

# %%
# Order our Data a little bit to see

df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
# ...                                          ...    ...     ...   ...
# 7663                                More to Life    NaN   Drama  2020
# 7664                                 Dream Round    NaN  Comedy  2020
# 7665                               Saving Mbango    NaN   Drama  2020
# 7666                                It's Just Us    NaN   Drama  2020
# 7667                                   Tee em el    NaN  Horror  2020
#
#                                released  score      votes       director  \
# ...

# %%
# Sort the DataFrame by gross earnings in descending order and save the result
sorted_df = df.sort_values(by=['gross'], ascending=False)

# Display the top 10 highest-grossing movies
print("Top 10 Highest-Grossing Movies:")
top_movies = sorted_df.head(10)

# Create a more informative display with selected columns
# Adjust the columns based on what's available in your dataset
# Common movie dataset columns include: title, director, year, gross, budget, rating, etc.
display_columns = ['title', 'director', 'year', 'gross', 'budget'] 
display_columns = [col for col in display_columns if col in sorted_df.columns]

# Display the formatted results
print(top_movies[display_columns].reset_index(drop=True))

# Calculate return on investment if budget column exists
if 'budget' in sorted_df.columns and 'gross' in sorted_df.columns:
    # Add ROI column (Return on Investment)
    sorted_df['roi'] = (sorted_df['gross'] - sorted_df['budget']) / sorted_df['budget'] * 100
    
    # Show top 10 movies by ROI (most profitable)
    print("\nTop 10 Most Profitable Movies (by ROI):")
    top_roi = sorted_df.sort_values(by=['roi'], ascending=False).head(10)
    roi_columns = display_columns + ['roi'] if 'roi' not in display_columns else display_columns
    print(top_roi[roi_columns].reset_index(drop=True))

# Show summary statistics for top movies vs. overall dataset
print("\nComparison of Top 10 Movies vs. Overall Dataset:")
if 'gross' in sorted_df.columns:
    print(f"Average gross for top 10 movies: ${top_movies['gross'].mean():,.2f}")
    print(f"Average gross for all movies: ${sorted_df['gross'].mean():,.2f}")
    print(f"Highest gross: ${sorted_df['gross'].max():,.2f}")
    print(f"Lowest gross: ${sorted_df['gross'].min():,.2f}")

# Return the sorted DataFrame for further use
sorted_df
# Out:
# Top 10 Highest-Grossing Movies:
#           director  year         gross       budget
# 0    James Cameron  2009  2.847246e+09  237000000.0
# 1    Anthony Russo  2019  2.797501e+09  356000000.0
# 2    James Cameron  1997  2.201647e+09  200000000.0
# 3      J.J. Abrams  2015  2.069522e+09  245000000.0
# 4    Anthony Russo  2018  2.048360e+09  321000000.0
# 5      Jon Favreau  2019  1.670728e+09  260000000.0
# 6  Colin Trevorrow  2015  1.670516e+09  150000000.0
# 7      Joss Whedon  2012  1.518816e+09  220000000.0
# 8        James Wan  2015  1.515341e+09  190000000.0
# 9       Chris Buck  2019  1.450027e+09  150000000.0
#
# Top 10 Most Profitable Movies (by ROI):
#            director  year        gross    budget           roi
# 0         Oren Peli  2007  193355800.0   15000.0  1.288939e+06
# 1     Daniel Myrick  1999  248639099.0   60000.0  4.142985e+05
# 2      Travis Cluff  2015   42964410.0  100000.0  4.286441e+04
# 3  Robert Rodriguez  1992    2040920.0    7000.0  2.905600e+04
# ...

# %%
plt.figure(figsize=(12, 6))  # Adjust figure size for better readability
sns.regplot(x="budget", y="gross", data=df, 
            scatter_kws={'color': 'blue', 'alpha': 0.5},  # Customize scatter points
            line_kws={'color': 'red', 'linewidth': 3},   # Customize regression line
            marker='o')  # Use circular markers for scatter points

# Improve labels and title
plt.xlabel("Movie Budget (in millions)", fontsize=14)
plt.ylabel("Gross Revenue (in millions)", fontsize=14)
plt.title("Relationship Between Budget and Gross Revenue", fontsize=16, fontweight="bold")

# Add a grid for better readability
plt.grid(True, linestyle="--", alpha=0.5)

# Show the plot
plt.show()

# %%
plt.figure(figsize=(12, 6))  # Set figure size for better readability

sns.regplot(x="score", y="gross", data=df, 
            scatter_kws={'color': 'blue', 'alpha': 0.5, 's': 50},  # Customize scatter points
            line_kws={'color': 'red', 'linewidth': 2},  # Customize regression line
            marker='o')  # Use circular markers

# Improve Labels and Title
plt.xlabel("IMDB Score / Rating", fontsize=14, fontweight='bold', color='black')
plt.ylabel("Gross Revenue (in millions)", fontsize=14, fontweight='bold', color='black')
plt.title("Relationship Between IMDB Score and Gross Revenue", fontsize=16, fontweight="bold", color='darkblue')

# Enhance x-axis & y-axis ticks for better readability
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Add a grid for better readability
plt.grid(True, linestyle="--", alpha=0.5)

# Show the plot
plt.show()

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include=[np.number])

# Optionally, handle missing values (e.g., by filling with the mean)
numeric_df = numeric_df.fillna(numeric_df.mean())

# Compute the correlation matrix
correlation_matrix = numeric_df.corr(method='pearson')

print(correlation_matrix)
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097936  0.222810  0.265578  0.252042  0.120766
# score    0.097936  1.000000  0.409182  0.064541  0.182868  0.399329
# votes    0.222810  0.409182  1.000000  0.421007  0.628713  0.309166
# budget   0.265578  0.064541  0.421007  1.000000  0.711270  0.265287
# gross    0.252042  0.182868  0.628713  0.711270  1.000000  0.241335
# runtime  0.120766  0.399329  0.309166  0.265287  0.241335  1.000000

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include=[np.number])

# Optionally, handle missing values (e.g., by filling with the mean)
numeric_df = numeric_df.fillna(numeric_df.mean())

# Compute the correlation matrix
correlation_matrix = numeric_df.corr(method='spearman')

print(correlation_matrix)
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.098869  0.470008  0.202558  0.267101  0.143114
# score    0.098869  1.000000  0.428026  0.004842  0.117961  0.399451
# votes    0.470008  0.428026  1.000000  0.234535  0.688687  0.290105
# budget   0.202558  0.004842  0.234535  1.000000  0.361668  0.227859
# gross    0.267101  0.117961  0.688687  0.361668  1.000000  0.227986
# runtime  0.143114  0.399451  0.290105  0.227859  0.227986  1.000000

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include=[np.number])

# Optionally, handle missing values (e.g., by filling with the mean)
numeric_df = numeric_df.fillna(numeric_df.mean())

# Compute the correlation matrix using the 'kendall' method
correlation_matrix = numeric_df.corr(method='kendall')

print(correlation_matrix)
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.067518  0.331581  0.144258  0.182415  0.097271
# score    0.067518  1.000000  0.300035  0.003606  0.080332  0.283303
# votes    0.331581  0.300035  1.000000  0.161337  0.508040  0.198199
# budget   0.144258  0.003606  0.161337  1.000000  0.258476  0.161710
# gross    0.182415  0.080332  0.508040  0.258476  1.000000  0.156135
# runtime  0.097271  0.283303  0.198199  0.161710  0.156135  1.000000

# %%
correlation_matrix = df_numeric.corr()

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Numeric Features")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your dataset (if not already loaded)
# df = pd.read_csv("your_dataset.csv")  

# Selecting only numeric columns
df_numeric = df.select_dtypes(include=['number'])  # Extracts only numerical features

# Compute correlation matrix
correlation_matrix = df_numeric.corr()

# Set up the figure size for better readability
plt.figure(figsize=(12, 8))

# Generate heatmap
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)

# Add title and labels
plt.title("Correlation Matrix for Numeric Features", fontsize=14, fontweight="bold")
plt.xlabel("Movie Features", fontsize=12)
plt.ylabel("Movie Features", fontsize=12)

# Show the plot
plt.show()

# %%
df.apply(lambda x: x.factorize()[0]).corr(method='pearson')
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000  0.143938  0.036367  0.965761  0.959015 -0.046733
# rating    0.143938  1.000000 -0.086723  0.156713  0.146606  0.012595
# genre     0.036367 -0.086723  1.000000  0.037184  0.035940 -0.002437
# year      0.965761  0.156713  0.037184  1.000000  0.993190 -0.044981
# released  0.959015  0.146606  0.035940  0.993190  1.000000 -0.045761
# score    -0.046733  0.012595 -0.002437 -0.044981 -0.045761  1.000000
# votes     0.287776  0.099972  0.023285  0.312401  0.299905 -0.009749
# director  0.745905  0.085520  0.047288  0.770497  0.770876 -0.022687
# writer    0.805211  0.103623  0.033688  0.824770  0.819617 -0.034685
# star      0.731565  0.093116  0.038649  0.756400  0.754468 -0.009896
# country   0.142828  0.000494 -0.015795  0.140216  0.148468  0.023097
# budget    0.277488  0.193353  0.073008  0.300621  0.285691 -0.012642
# gross     0.947324  0.158582  0.038616  0.980873  0.976423 -0.047041
# ...

# %%
correlation_matrix = df.apply(lambda x: x.factorize()[0]).corr(method='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Movies")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load your dataset (if not already loaded)
# df = pd.read_csv("your_dataset.csv")  

# Factorize only categorical columns
df_factorized = df.copy()
for col in df.select_dtypes(include=['object']).columns:  # Select only categorical columns
    df_factorized[col], _ = df[col].factorize()  # Convert categorical values to numerical labels

# Compute Correlation Matrix
correlation_matrix = df_factorized.corr(method='pearson')

# Set up the figure size for better readability
plt.figure(figsize=(12, 8))

# Generate heatmap with better color and formatting
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)

# Add title and labels for better understanding
plt.title("Correlation Matrix for Movies", fontsize=14, fontweight="bold")
plt.xlabel("Movie Features", fontsize=12)
plt.ylabel("Movie Features", fontsize=12)

# Show the plot
plt.show()

# %%
correlation_mat = df.apply(lambda x: x.factorize()[0]).corr()

corr_pairs = correlation_mat.unstack()

print(corr_pairs)
# Out:
# name     name        1.000000
#          rating      0.143938
#          genre       0.036367
#          year        0.965761
#          released    0.959015
#                        ...
# runtime  country     0.124154
#          budget      0.112097
#          gross       0.042978
#          company     0.005137
#          runtime     1.000000
# Length: 225, dtype: float64

# %%
correlation_mat = df.apply(lambda x: x.factorize()[0]).corr()

# Convert matrix into list format
corr_pairs = correlation_mat.unstack()

# Sort pairs based on absolute correlation value (ignoring self-correlations)
sorted_corr_pairs = corr_pairs.abs().sort_values(ascending=False)

# Display the top 10 strongest correlations (excluding self-correlations)
print(sorted_corr_pairs[sorted_corr_pairs < 1].head(10))
# Out:
# released  year        0.993190
# year      released    0.993190
# gross     year        0.980873
# year      gross       0.980873
# gross     released    0.976423
# released  gross       0.976423
# name      year        0.965761
# year      name        0.965761
# name      released    0.959015
# released  name        0.959015
# dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values(kind="quicksort")

print(sorted_pairs)
# Out:
# budget   company   -0.092249
# company  budget    -0.092249
# genre    rating    -0.086723
# rating   genre     -0.086723
# budget   country   -0.082082
#                       ...
# year     year       1.000000
# genre    genre      1.000000
# rating   rating     1.000000
# company  company    1.000000
# runtime  runtime    1.000000
# Length: 225, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values(kind="quicksort")

# Exclude self-correlations (which are always 1.00)
filtered_sorted_pairs = sorted_pairs[sorted_pairs < 1]

# Print the top 10 strongest correlations
print(filtered_sorted_pairs.tail(10))  # Last 10 values (highest correlations)
# Out:
# name      released    0.959015
# released  name        0.959015
# name      year        0.965761
# year      name        0.965761
# released  gross       0.976423
# gross     released    0.976423
# year      gross       0.980873
# gross     year        0.980873
# released  year        0.993190
# year      released    0.993190
# dtype: float64

# %%
strong_pairs = sorted_pairs[abs(sorted_pairs) > 0.5]

print(strong_pairs)
# Out:
# star      company    0.527116
# company   star       0.527116
#           writer     0.546151
# writer    company    0.546151
# director  company    0.552258
#                        ...
# year      year       1.000000
# genre     genre      1.000000
# rating    rating     1.000000
# company   company    1.000000
# runtime   runtime    1.000000
# Length: 71, dtype: float64

# %%
# Filter strong correlations (excluding self-correlations)
strong_pairs = sorted_pairs[(abs(sorted_pairs) > 0.5) & (abs(sorted_pairs) < 1)]

# Display the top 10 highest correlations
print(strong_pairs.tail(10))  # Shows last 10 values (highest correlations)
# Out:
# name      released    0.959015
# released  name        0.959015
# name      year        0.965761
# year      name        0.965761
# released  gross       0.976423
# gross     released    0.976423
# year      gross       0.980873
# gross     year        0.980873
# released  year        0.993190
# year      released    0.993190
# dtype: float64

# %%
# Looking at the top 15 compaies by gross revenue

CompanyGrossSum = df.groupby('company')[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values('gross', ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company
# Warner Bros.                 56491421806
# Universal Pictures           52514188890
# Columbia Pictures            43008941346
# Paramount Pictures           40493607415
# Twentieth Century Fox        40257053857
# Walt Disney Pictures         36327887792
# New Line Cinema              19883797684
# Marvel Studios               15065592411
# DreamWorks Animation         11873612858
# Touchstone Pictures          11795832638
# Dreamworks Pictures          11635441081
# Metro-Goldwyn-Mayer (MGM)     9230230105
# Summit Entertainment          8373718838
# Pixar Animation Studios       7886344526
# Fox 2000 Pictures             7443502667
# Name: gross, dtype: int64

# %%
# Group by company and sum gross revenue
CompanyGrossSum = df.groupby('company')[["gross"]].sum()

# Sort companies by total gross revenue (descending) and select top 15
CompanyGrossSumSorted = CompanyGrossSum.sort_values('gross', ascending=False).head(15)

# Convert gross revenue to integer format
CompanyGrossSumSorted['gross'] = CompanyGrossSumSorted['gross'].astype(int)

# Display the result
print(CompanyGrossSumSorted)
# Out:
#                                 gross
# company
# Warner Bros.              -2147483648
# Universal Pictures        -2147483648
# Columbia Pictures         -2147483648
# Paramount Pictures        -2147483648
# Twentieth Century Fox     -2147483648
# Walt Disney Pictures      -2147483648
# New Line Cinema           -2147483648
# Marvel Studios            -2147483648
# DreamWorks Animation      -2147483648
# Touchstone Pictures       -2147483648
# Dreamworks Pictures       -2147483648
# Metro-Goldwyn-Mayer (MGM) -2147483648
# Summit Entertainment      -2147483648
# Pixar Animation Studios   -2147483648
# Fox 2000 Pictures         -2147483648

# %%
df['Year'] = df['released'].astype(str).str[:4]
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
# Ensure 'released' is a string and extract the first 4 characters safely
df['Year'] = df['released'].astype(str).str.extract(r'(^\d{4})')

# Display the DataFrame
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df.groupby(['company', 'year'])[["gross"]].sum()
# Out:
#                                                 gross
# company                             year
# "DIA" Productions GmbH & Co. KG     2003   44350926.0
# "Weathering With You" Film Partners 2019  193457467.0
# .406 Production                     1996      10580.0
# 1+2 Seisaku Iinkai                  2000    1196218.0
# 10 West Studios                     2010     814906.0
# ...                                               ...
# i am OTHER                          2015   17986781.0
# i5 Films                            2001   10031529.0
# iDeal Partners Film Fund            2013     506303.0
# micro_scope                         2010    7099598.0
# thefyzz                             2017   62198461.0
#
# [4536 rows x 1 columns]

# %%
CompanyGrossSum = df.groupby(['company', 'year'])[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values(['gross','company','year'], ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company                year
# Walt Disney Pictures   2019    5773131804
# Marvel Studios         2018    4018631866
# Universal Pictures     2015    3834354888
# Twentieth Century Fox  2009    3793491246
# Walt Disney Pictures   2017    3789382071
# Paramount Pictures     2011    3565705182
# Warner Bros.           2010    3300479986
#                        2011    3223799224
# Walt Disney Pictures   2010    3104474158
# Paramount Pictures     2014    3071298586
# Columbia Pictures      2006    2934631933
#                        2019    2932757449
# Marvel Studios         2019    2797501328
# Warner Bros.           2018    2774168962
# Columbia Pictures      2011    2738363306
# Name: gross, dtype: int64

# %%
CompanyGrossSum = df.groupby(['company'])[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values(['gross','company'], ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company
# Warner Bros.                 56491421806
# Universal Pictures           52514188890
# Columbia Pictures            43008941346
# Paramount Pictures           40493607415
# Twentieth Century Fox        40257053857
# Walt Disney Pictures         36327887792
# New Line Cinema              19883797684
# Marvel Studios               15065592411
# DreamWorks Animation         11873612858
# Touchstone Pictures          11795832638
# Dreamworks Pictures          11635441081
# Metro-Goldwyn-Mayer (MGM)     9230230105
# Summit Entertainment          8373718838
# Pixar Animation Studios       7886344526
# Fox 2000 Pictures             7443502667
# Name: gross, dtype: int64

# %%
plt.scatter(x=df['budget'], y=df['gross'], alpha=0.5)
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))  # Adjust figure size

# Create scatter plot with improved visuals
sns.scatterplot(x=df['budget'], y=df['gross'], alpha=0.6, color="blue", edgecolor='black')

# Add regression trend line
sns.regplot(x=df['budget'], y=df['gross'], scatter=False, color='red', ci=None)

# Set proper axis labels
plt.title('Budget vs Gross Earnings', fontsize=14)
plt.xlabel('Budget for Film', fontsize=12)
plt.ylabel('Gross Earnings', fontsize=12)

# Display the plot
plt.show()

# %%
for col_name in df.select_dtypes(include=['object']).columns:
    df[col_name] = df[col_name].astype('category')
    df[col_name] = df[col_name].cat.codes  # Assign numerical codes

    print(f"Converted '{col_name}' to categorical codes.")
# Out:
# Converted 'name' to categorical codes.
# Converted 'rating' to categorical codes.
# Converted 'genre' to categorical codes.
# Converted 'released' to categorical codes.
# Converted 'director' to categorical codes.
# Converted 'writer' to categorical codes.
# Converted 'star' to categorical codes.
# Converted 'country' to categorical codes.
# Converted 'company' to categorical codes.
# Converted 'Year' to categorical codes.

# %%
df
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1     5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2     5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3      286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4     1027       6      4  1980      1543    7.3   108000.0      1054     521
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7663  3705      -1      6  2020      2964    3.1       18.0      1500    2289
# 7664  1678      -1      4  2020      1107    4.7       36.0       774    2614
# 7665  4717      -1      6  2020       193    5.7       29.0      2061    2683
# 7666  2843      -1      6  2020      2817    NaN        NaN      1184    1824
# 7667  5394      -1     10  2020       391    5.7        7.0      2165    3344
#
# ...

# %%
df[cat_columns] = df[cat_columns].apply(lambda x: x.cat.codes)

df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df[cat_columns] = df[cat_columns].apply(lambda x: x.cat.codes)
#       3 df
#
# NameError: name 'cat_columns' is not defined

# %%
# Step 1: Identify categorical columns automatically
cat_columns = df.select_dtypes(include=['object', 'category']).columns

# Step 2: Convert categorical columns to category type
df[cat_columns] = df[cat_columns].apply(lambda x: x.astype('category'))

# Step 3: Convert category values to numeric codes
df[cat_columns] = df[cat_columns].apply(lambda x: x.cat.codes)

df
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1     5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2     5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3      286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4     1027       6      4  1980      1543    7.3   108000.0      1054     521
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7663  3705      -1      6  2020      2964    3.1       18.0      1500    2289
# 7664  1678      -1      4  2020      1107    4.7       36.0       774    2614
# 7665  4717      -1      6  2020       193    5.7       29.0      2061    2683
# 7666  2843      -1      6  2020      2817    NaN        NaN      1184    1824
# 7667  5394      -1     10  2020       391    5.7        7.0      2165    3344
#
# ...

# %%
plt.figure(figsize=(12,6))
sns.violinplot(x="rating", y="gross", data=df)
plt.title("Distribution of Gross Revenue by Movie Rating")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="rating", y="gross", data=df)
plt.title("Gross Revenue by Movie Rating (Boxplot)")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.stripplot(x="rating", y="gross", hue="genre", data=df, dodge=True, jitter=True)
plt.title("Gross Revenue by Movie Rating and Genre")
plt.show()
